# %% [markdown]
# ## Использование Pandas

# %%
import pandas as pd

# %% [markdown]
# ### 1. Выполнить загрузку CSV-файла в память посредством Pandas.

# %%
df = pd.read_csv("data-20220204T1151-structure-20220204T1151.csv")
df
# Out:
#      №\r\nсертификата Дата\r\nвнесения\r\nв реестр  \
# 0                17/1                   26.07.2002
# 1                21/2                   25.06.2013
# 2                27/1                   24.05.2005
# 3                32/1                   20.04.1996
# 4                32/2                   20.04.1996
# ...               ...                          ...
# 1919             4510                   14.01.2022
# 1920             4513                   19.01.2022
# 1921             4514                   20.01.2022
# 1922             4516                   25.01.2022
# 1923             4517                   02.02.2022
#
#      Срок\r\nдействия\r\nсертификата  \
# 0                         01.08.2020
# 1                         25.06.2019
# 2                         24.05.2020
# 3                         17.04.2021
# 4                         17.04.2021
# ...                              ...
# 1919                            #Н/Д
# 1920                      19.01.2027
# ...

# %% [markdown]
# ### 2. Показать список уникальных наименований документов, требованиям которых соответствуют представленные средства защиты информации.

# %%
a = df['Наименования документов, требованиям которых соответствует средство'].unique()
print(a)
# Out:
# ['Соответствует требованиям документов: Требования к ПСЗ ПЭМИН-2015'
#  'Соответствует требованиям документов: РД СВТ(2)'
#  'Соответствует требованиям документов: ТУ'
#  'Соответствует требованиям документов: РД САЗ ПЭМИН-87'
#  'Соответствует требованиям документов: РД САЗ ПЭМИН-87, ТУ'
#  'Соответствует требованиям документов: Требования к САЗ ПЭМИН-2014(А), Требования к САЗ ПЭМИН-2014(Б)'
#  'Соответствует требованиям документов: НМД ПЭМИН-1998, ТУ'
#  'Соответствует требованиям документов: НМД АРР-2000, ТУ'
#  'Соответствует требованиям документов: НМД АРР-2000'
#  'Соответствует требованиям документов: РД НДВ(3), РД СВТ(4)'
#  'Соответствует требованиям документов: Требования к СДЗ, Профиль защиты СДЗ(платы расширения второго класса защиты. ИТ.СДЗ.ПР2.ПЗ)'
#  'Соответствует требованиям документов: РД НДВ(3)'
#  'Соответствует требованиям документов: ТЗИ НСД СУиК ЯМ-1997(3)'
#  'Соответствует требованиям документов: РД НДВ(2), РД СВТ(2)'
# ...

# %% [markdown]
# ### 3. Отобразить список наименований средств, соответствующих двум любым документам с требованиями по сертификации.

# %%
options = ['Соответствует требованиям документов: ТУ',  'Соответствует требованиям документов: РД СПФ, ТУ'] 
    
# selecting rows based on condition 
rslt_df = df[df['Наименования документов, требованиям которых соответствует средство'].isin(options)] 
rslt_df
# Out:
#      №\r\nсертификата Дата\r\nвнесения\r\nв реестр  \
# 2                27/1                   24.05.2005
# 39             263/17                   03.08.2007
# 51                371                   16.10.2000
# 52                404                   19.12.2000
# 55              604/2                   07.04.2005
# ...               ...                          ...
# 1771             4354                   28.12.2020
# 1832             4418                   08.06.2021
# 1834             4420                   08.06.2021
# 1851             4439                   18.08.2021
# 1864             4452                   26.10.2021
#
#      Срок\r\nдействия\r\nсертификата  \
# 2                         24.05.2020
# 39                        03.08.2019
# 51                        05.12.2023
# 52                        23.01.2024
# 55                        07.04.2020
# ...                              ...
# 1771                      28.12.2025
# 1832                      08.06.2026
# ...

# %% [markdown]
# ### 4. Показать наименования тех средств, которые имеют просроченные сертификаты (намомент выполнения задания).

# %%
from datetime import datetime, timedelta
from pandas import DataFrame

# %%
df['Срок\r\nдействия\r\nсертификата'] = pd.to_datetime(df['Срок\r\nдействия\r\nсертификата'], format='%d.%m.%Y', errors='coerce')

# %%
df.dtypes
# Out:
# №\r\nсертификата                                                                        object
# Дата\r\nвнесения\r\nв реестр                                                            object
# Срок\r\nдействия\r\nсертификата                                                 datetime64[ns]
# Наименование\r\nсредства (шифр)                                                         object
# Наименования документов, требованиям которых соответствует средство                     object
# Схема\r\nсертификации                                                                   object
# Испытательная\r\nлаборатория                                                            object
# Орган по\r\nсертификации                                                                object
# Заявитель                                                                               object
# Реквизиты заявителя\r\n(индекс, адрес, телефон)                                         object
# ...

# %%
df[(df['Срок\r\nдействия\r\nсертификата'] < '2022-12-13') ]
# Out:
#      №\r\nсертификата Дата\r\nвнесения\r\nв реестр  \
# 0                17/1                   26.07.2002
# 1                21/2                   25.06.2013
# 2                27/1                   24.05.2005
# 3                32/1                   20.04.1996
# 4                32/2                   20.04.1996
# ...               ...                          ...
# 1401             3973                   25.07.2018
# 1402             3974                   25.07.2018
# 1404             3976                   27.07.2018
# 1405             3977                   01.08.2018
# 1887             4475                   24.11.2021
#
#      Срок\r\nдействия\r\nсертификата  \
# 0                         2020-08-01
# 1                         2019-06-25
# 2                         2020-05-24
# 3                         2021-04-17
# 4                         2021-04-17
# ...                              ...
# 1401                      2021-07-25
# 1402                      2021-07-25
# ...

# %% [markdown]
# ### 5. Показать наименования тех средств, которые имеют просроченные сертификаты, но при этом обязаны оказывать поддержку (столбец «Информация об окончании срока технической поддержки, полученная от заявителя»).

# %%
df['Информация об окончании срока технической поддержки, полученная от заявителя'] = pd.to_datetime(df['Информация об окончании срока технической поддержки, полученная от заявителя'], format='%d.%m.%Y', errors='coerce')

# %%
df.dtypes
# Out:
# №\r\nсертификата                                                                        object
# Дата\r\nвнесения\r\nв реестр                                                            object
# Срок\r\nдействия\r\nсертификата                                                 datetime64[ns]
# Наименование\r\nсредства (шифр)                                                         object
# Наименования документов, требованиям которых соответствует средство                     object
# Схема\r\nсертификации                                                                   object
# Испытательная\r\nлаборатория                                                            object
# Орган по\r\nсертификации                                                                object
# Заявитель                                                                               object
# Реквизиты заявителя\r\n(индекс, адрес, телефон)                                         object
# ...

# %%
df[(df['Срок\r\nдействия\r\nсертификата'] < '2022-12-13') & (df['Информация об окончании срока технической поддержки, полученная от заявителя'] > '2022-12-13')]
# Out:
#      №\r\nсертификата Дата\r\nвнесения\r\nв реестр  \
# 0                17/1                   26.07.2002
# 3                32/1                   20.04.1996
# 4                32/2                   20.04.1996
# 11                 66                   26.12.1996
# 24              214/1                   26.07.2002
# ...               ...                          ...
# 1376             3948                   31.05.2018
# 1377             3949                   05.06.2018
# 1378             3950                   05.06.2018
# 1384             3956                   22.06.2018
# 1404             3976                   27.07.2018
#
#      Срок\r\nдействия\r\nсертификата  \
# 0                         2020-08-01
# 3                         2021-04-17
# 4                         2021-04-17
# 11                        2021-01-24
# 24                        2020-08-01
# ...                              ...
# 1376                      2021-05-31
# 1377                      2021-06-05
# ...

# %% [markdown]
# ### 6. Показать наименования всех средств, которые проходили испытания в частных организациях (форма организации ООО, ЗАО, ПАО, АО).

# %%
df[df['Испытательная\r\nлаборатория'].str.contains("ООО|ЗАО|ПАО|АО")]
# Out:
#      №\r\nсертификата Дата\r\nвнесения\r\nв реестр  \
# 1                21/2                   25.06.2013
# 2                27/1                   24.05.2005
# 5             41/5/10                   30.03.2011
# 6             41/5/17                   18.04.2013
# 7              41/6/5                   09.03.2011
# ...               ...                          ...
# 1919             4510                   14.01.2022
# 1920             4513                   19.01.2022
# 1921             4514                   20.01.2022
# 1922             4516                   25.01.2022
# 1923             4517                   02.02.2022
#
#      Срок\r\nдействия\r\nсертификата  \
# 1                         2019-06-25
# 2                         2020-05-24
# 5                         2020-03-30
# 6                         2019-04-18
# 7                         2020-03-09
# ...                              ...
# 1919                             NaT
# 1920                      2027-01-19
# ...
